# %% [markdown]
# # Google mobility trends
# We analyse google mobility data during COVID19.
# The main idea is to show how mobility has changed during COVID19.
# We use the open data from https://github.com/datasciencecampus/google-mobility-reports-data

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
filepath_loc ="C:/Users/lyubo/Documents/DATA_networks/covid19/google-mobility-reports-data-master/csvs/international_local_area_trends_UK_DE_FR_ES_IT_US_SE.csv"
filepath_nat ="C:/Users/lyubo/Documents/DATA_networks/covid19/google-mobility-reports-data-master/csvs/international_national_trends_UK_DE_FR__ES_IT_US_SE.csv"

data_mob_loc = pd.read_csv(filepath_loc)
print(data_mob_loc.shape)
data_mob_loc.head()
# Out:
# (1739, 48)
#   Country       location       category codes  2020-02-16  2020-02-17  \
# 0      UK  Aberdeen City    retail_recr    GB         6.0        11.0
# 1      UK  Aberdeen City  grocery_pharm    GB         0.0         0.0
# 2      UK  Aberdeen City          parks    GB       -13.0        24.0
# 3      UK  Aberdeen City        transit    GB         4.0         2.0
# 4      UK  Aberdeen City      workplace    GB         2.0       -10.0
#
#    2020-02-18  2020-02-19  2020-02-20  2020-02-21  ...  2020-03-21  \
# 0         5.0         2.0        -1.0         0.0  ...       -57.0
# 1         0.0        -2.0         3.0        -1.0  ...         1.0
# 2        26.0         9.0        -1.0       -10.0  ...       -12.0
# 3         1.0         4.0        -1.0        -3.0  ...       -44.0
# 4        -6.0        -6.0         1.0        -1.0  ...       -26.0
#
#    2020-03-22  2020-03-23  2020-03-24  2020-03-25  2020-03-26  2020-03-27  \
# ...

# %%
import numpy as np
# find unique values of Country 
un_count = np.unique(data_mob_loc['Country'].values)

print(un_count)
# Out:
# ['France' 'Germany' 'Italy' 'Spain' 'Sweden' 'UK' 'USA']

# %%
# get only df for France
df_France = data_mob_loc[data_mob_loc['Country']=="France"]
df_France.head()
# Out:
#      Country              location       category codes  2020-02-16  \
# 1661  France  Auvergne-Rhône-Alpes    retail_recr    FR        15.0
# 1662  France  Auvergne-Rhône-Alpes  grocery_pharm    FR        15.0
# 1663  France  Auvergne-Rhône-Alpes          parks    FR        44.0
# 1664  France  Auvergne-Rhône-Alpes        transit    FR        18.0
# 1665  France  Auvergne-Rhône-Alpes      workplace    FR         1.0
#
#       2020-02-17  2020-02-18  2020-02-19  2020-02-20  2020-02-21  ...  \
# 1661         2.0         8.0        -1.0         6.0         7.0  ...
# 1662         6.0         7.0         4.0         6.0         6.0  ...
# 1663        22.0        56.0        19.0        58.0        42.0  ...
# 1664         5.0         8.0         4.0        10.0        18.0  ...
# 1665         1.0         2.0         1.0         1.0         0.0  ...
#
#       2020-03-21  2020-03-22  2020-03-23  2020-03-24  2020-03-25  2020-03-26  \
# ...

# %%
import numpy as np
# find unique values of Country 
un_count = np.unique(df_France['location'].values)

print('unique locations for France',un_count)
# Out:
# unique locations for France ['Auvergne-Rhône-Alpes' 'Bourgogne-Franche-Comté' 'Brittany'
#  'Centre-Val de Loire' 'Corsica' 'Grand Est' 'Hauts-de-France' 'Normandy'
#  'Nouvelle-Aquitaine' 'Occitanie' 'Pays de la Loire'
#  "Provence-Alpes-Côte d'Azur" 'Île-de-France']

# %%
# create Ile de France mobility data 

df_ile_de_fr = df_France[df_France['location'] =='Île-de-France']

print(df_ile_de_fr.shape)
df_ile_de_fr.head(6)
# Out:
# (6, 48)
#      Country       location       category codes  2020-02-16  2020-02-17  \
# 1733  France  Île-de-France    retail_recr    FR        -6.0        -2.0
# 1734  France  Île-de-France  grocery_pharm    FR        -6.0        -3.0
# 1735  France  Île-de-France          parks    FR        -8.0        11.0
# 1736  France  Île-de-France        transit    FR         4.0       -11.0
# 1737  France  Île-de-France      workplace    FR        -1.0       -20.0
# 1738  France  Île-de-France    residential    FR        -2.0         4.0
#
#       2020-02-18  2020-02-19  2020-02-20  2020-02-21  ...  2020-03-21  \
# 1733        -1.0        -7.0        -3.0        -4.0  ...       -88.0
# 1734        -2.0        -9.0        -9.0        -3.0  ...       -51.0
# 1735        15.0        -5.0        -1.0         8.0  ...       -89.0
# 1736        -8.0       -10.0        -8.0        -6.0  ...       -82.0
# 1737       -18.0       -15.0       -19.0       -18.0  ...       -64.0
# ...

# %% [markdown]
# # Plotting mobility trends

# %%
plt.figure(figsize=(20,10))

for ind in range(0,6): # plot each category
    row = df_ile_de_fr.iloc[ind,4:48].values
    #print(row)
    plt.plot(row, label = df_ile_de_fr['category'].iloc[ind])

    plt.xlabel("time")
    plt.ylabel("value")
plt.legend(title ='mobility trend' )
plt.title("mobility trend in Ile de France, 2020-02-16 - 2020-03-29")
plt.show()

# %% [markdown]
# # Plotting in national trends

# %%
filepath_nat ="C:/Users/lyubo/Documents/DATA_networks/covid19/google-mobility-reports-data-master/csvs/international_national_trends_UK_DE_FR__ES_IT_US_SE.csv"

data_mob_nat = pd.read_csv(filepath_nat)
print('shape', data_mob_nat.shape)
data_mob_nat.head()
import numpy as np
# find unique values of Country 
un_count = np.unique(data_mob_nat['Country'].values)

print(un_count)


# get only df for France
df_France_nation = data_mob_nat[data_mob_nat['Country']=="France"]
df_France_nation.head()
# Out:
# shape (42, 46)
# ['France' 'Germany' 'Italy' 'Spain' 'Sweden' 'UK' 'USA']
#    Country Country code             Category  16/02/2020  17/02/2020  \
# 36  France           FR  Retail & recreation           6           1
# 37  France           FR   Grocery & pharmacy           2           2
# 38  France           FR                Parks           9          16
# 39  France           FR     Transit stations           7          -6
# 40  France           FR            Workplace          -1         -15
#
#     18/02/2020  19/02/2020  20/02/2020  21/02/2020  22/02/2020  ...  \
# 36           5          -4          -2          -1          -6  ...
# 37           2          -3          -1          -2          -2  ...
# 38          36          18          29          28          31  ...
# 39          -4          -6          -4           0          14  ...
# 40         -14         -12         -15         -15          -5  ...
#
# ...

# %%
plt.figure(figsize=(20,10))

for ind in range(0,6): # plot each county data
    row = df_France_nation.iloc[ind,3:46].values
    #print(row)
    plt.plot(row, marker ='o', label = df_France_nation['Category'].iloc[ind])

    plt.xlabel("time")
    plt.ylabel("value")
plt.legend(title ='Mobility index')
plt.title("Mobility trend in France")
plt.show()

# %% [markdown]
# # Plotting with classification
# Based on density.
#
# Now let us plot mobility trends using information about density of population as we did for county level in USA.
# See data on population in NASA website.

# %%
plt.figure(figsize=(20,10))

for ind in range(0,22): # plot each county data
    row = data_covid.iloc[ind,3:29].values
    #print(row)
    if (int(data_covid.iloc[ind,0]) == 0):#high cluster value
        clr = 'r'
    else:
        clr = 'b'
        
    plt.loglog(row, marker ='o', color = clr, label = ind)

    plt.xlabel("time (rescaled)")
    plt.ylabel("value")
plt.legend(title ='States index')
plt.title("StateX, red for low density, 1 for higher density")
plt.show()
